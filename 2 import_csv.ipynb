# %%
import pandas as pd

# import data file into data frame
df = pd.read_csv("Food.csv")
df
# Out:
#                               Food_Item    Category   Size  Woolworths  \
# A001  Simba Beef Flavoured Potato Chips      Snacks   125g       18.49
# A002           Lays Salted Potato Chips      Snacks   125g       19.49
# A003          Coca-Cola Original Bottle   Beverages     2L       22.49
# A004                Fanta Orange Bottle   Beverages     2L       22.49
# A005  Cadbury Dairy Milk Chocolate Slab  Chocolates    80g       15.99
# A006   Nestlé Quality Street Chocolates  Chocolates   500g       99.99
# A007        Nescafé Gold Roasted Coffee      Coffee   200g      109.99
# A008      Jacobs Krönung Instant Coffee      Coffee   200g      109.99
# A009              All Gold Tomato Sauce      Sauces  700ml       30.99
# A010      Crosse & Blackwell Mayonnaise      Sauces   750g       33.99
#
#       Stock_Quantity_W  Checkers  Stock_Quantity_C  Pick_n_Pay  \
# A001                13     15.99                21       15.49
# ...
